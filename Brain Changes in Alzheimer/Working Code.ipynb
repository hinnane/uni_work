# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from pathlib import Path
import anndata
import time
import seaborn as sns

from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
# Change the download base to where the files are
download_base = Path('./data/abc_atlas')
abc_cache = AbcProjectCache.from_cache_dir(download_base)

abc_cache.current_manifest
# Out:
# 'releases/20250531/manifest.json'

# %%
abc_cache.list_data_files('MERFISH-C57BL6J-638850-imputed')
file = abc_cache.get_data_path(
    directory='MERFISH-C57BL6J-638850-imputed', file_name='C57BL6J-638850-imputed/log2')
print(file)
# Out:
# /Users/lindale/Downloads/data/abc_atlas/expression_matrices/MERFISH-C57BL6J-638850-imputed/20240831/C57BL6J-638850-imputed-log2.h5ad

# %%
adata = anndata.read_h5ad(file, backed='r')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 4334174 × 8460 backed at '/Users/lindale/Downloads/data/abc_atlas/expression_matrices/MERFISH-C57BL6J-638850-imputed/20240831/C57BL6J-638850-imputed-log2.h5ad'
#     obs: 'brain_section_label'
#     var: 'gene_symbol'

# %%
print("Number of genes = ", len(adata.var))
adata.var.index[0:5]
# Out:
# Number of genes =  8460
# Index(['ENSMUSG00000026676', 'ENSMUSG00000024517', 'ENSMUSG00000029361',
#        'ENSMUSG00000062372', 'ENSMUSG00000055639'],
#       dtype='object', name='gene_identifier')

# %%
# Load cell annotations
cell_anno = abc_cache.get_metadata_dataframe(
    directory='MERFISH-C57BL6J-638850',
    file_name='cell_metadata_with_cluster_annotation',
    dtype={"cell_label": str, "neurotransmitter": str}
)
cell_anno.set_index('cell_label', inplace=True)
print("Loaded cell_anno columns:", list(cell_anno.columns))
# Out:
# Loaded cell_anno columns: ['brain_section_label', 'cluster_alias', 'average_correlation_score', 'feature_matrix_label', 'donor_label', 'donor_genotype', 'donor_sex', 'x', 'y', 'z', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color']

# %%
# Create list of target genes
target_genes = ['Aif1', 'Gfap', 'S100b', 'Ache', 'Chat']  # removed Tnf

# Select the desired imputed genes
pred = [x in target_genes for x in adata.var.gene_symbol]
gene_filtered = adata.var[pred]

# Extract gene expression for the selected genes
gene_subset = adata[:, gene_filtered.index].to_df()

# Rename columns to gene symbols
gene_subset.rename(columns=gene_filtered.to_dict()['gene_symbol'], inplace=True)
print("Genes found in dataset:", list(gene_filtered.gene_symbol))
# Out:
# Genes found in dataset: ['S100b', 'Aif1', 'Chat', 'Ache', 'Gfap']

# %%
print(cell_anno.columns.tolist())
# Out:
# ['brain_section_label', 'cluster_alias', 'average_correlation_score', 'feature_matrix_label', 'donor_label', 'donor_genotype', 'donor_sex', 'x', 'y', 'z', 'neurotransmitter', 'class', 'subclass', 'supertype', 'cluster', 'neurotransmitter_color', 'class_color', 'subclass_color', 'supertype_color', 'cluster_color']

# %%
# Merge expression with metadata
joined = cell_anno.join(gene_subset, on='cell_label')

# Check columns and values exist
for col in ['class', 'neurotransmitter', 'subclass']:
    if col in joined.columns:
        print(f"✅ Column '{col}' exists. Unique values:")
        print(joined[col].unique())
        print("-" * 50)
    else:
        print(f"⚠ Column '{col}' does NOT exist in joined dataframe!")
# Out:
# ✅ Column 'class' exists. Unique values:
# ['04 DG-IMN Glut' '23 P Glut' '31 OPC-Oligo' '24 MY Glut' '19 MB Glut'
#  '26 P GABA' '20 MB GABA' '05 OB-IMN GABA' '30 Astro-Epen' '33 Vascular'
#  '27 MY GABA' '28 CB GABA' '09 CNU-LGE GABA' '01 IT-ET Glut' '12 HY GABA'
#  '29 CB Glut' '11 CNU-HYa GABA' '13 CNU-HYa Glut' '03 OB-CR Glut'
#  '34 Immune' '10 LSX GABA' '32 OEC' '02 NP-CT-L6b Glut' '08 CNU-MGE GABA'
#  '07 CTX-MGE GABA' '15 HY Gnrh1 Glut' '25 Pineal Glut' '06 CTX-CGE GABA'
#  '18 TH Glut' '14 HY Glut' '16 HY MM Glut' '21 MB Dopa' '17 MH-LH Glut'
#  '22 MB-HB Sero']
# --------------------------------------------------
# ✅ Column 'neurotransmitter' exists. Unique values:
# [nan 'Glut' 'Chol' 'GABA-Glyc' 'GABA' 'Dopa' 'Glut-GABA' 'Hist' 'Sero'
#  'Nora']
# --------------------------------------------------
# ✅ Column 'subclass' exists. Unique values:
# ['038 DG-PIR Ex IMN' '235 PG-TRN-LRN Fat2 Glut' '327 Oligo NN'
#  '261 HB Calcb Chol' '243 PGRN-PARN-MDRN Hoxb5 Glut' '157 RN Spp1 Glut'
#  '177 SCig-an-PPT Foxb1 Glut' '222 PB Evx2 Glut' '037 DG Glut'
#  '254 VCO Mafa Meis2 Glut' '278 NLL Gata3 Gly-Gaba' '197 SNr Six3 Gaba'
#  '045 OB-STR-CTX Inh IMN' '319 Astro-TE NN' '333 Endo NN'
#  '285 MY Lhx1 Gly-Gaba' '308 DCO Il22 Gly-Gaba' '039 OB Meis2 Thsd7b Gaba'
#  '250 CBN Neurod2 Pvalb Glut' '247 MV-SPIV Phox2b Ebf3 Lbx1 Glut'
#  '044 OB Dopa-Gaba' '217 PB Lmx1a Glut' '264 PRNc Otp Gly-Gaba'
#  '246 CU-ECU-SPVI Foxb1 Glut' '168 SPA-SPFm-SPFp-POL-PIL-PoT Sp9 Glut'
#  '282 POR Spp1 Gly-Gaba' '064 STR-PAL Chst9 Gaba' '233 NLL-SOC Spp1 Glut'
#  '224 PCG-PRNr Vsx2 Nkx6-1 Glut' '252 DMX VII Tbx20 Chol'
#  '164 APN C1ql4 Glut' '009 L2/3 IT PIR-ENTl Glut'
#  '160 PAG-SC Neurod2 Meis2 Glut' '313 CBX Purkinje Gaba'
#  '156 MB-ant-ve Dmrta2 Glut' '185 SCig Tfap2b Chrnb3 Glut'
#  '245 SPVI-SPVC Tlx3 Ebf3 Glut' '102 DMH-LHA Gsx1 Gaba'
#  '311 CBX MLI Megf11 Gaba' '248 MV-SPIV Zic4 Neurod2 Glut'
#  '042 OB-out Frmd7 Gaba' '318 Astro-NT NN' '221 LDT-PCG Vsx2 Lhx4 Glut'
#  '182 CUN-PPN Evx2 Meis2 Glut' '218 PSV Lmx1a Trpv6 Glut'
#  '314 CB Granule Glut' '238 NTS Phox2b Glut' '176 SCig Foxb1 Glut'
#  '066 NDB-SI-ant Prdm12 Gaba' '041 OB-in Frmd7 Gaba' '320 Astro-OLF NN'
#  '115 MS-SF Bsx Glut' '036 HPF CR Glut' '065 IA Mgp Gaba'
#  '334 Microglia NN' '304 NTS-PARN Neurod2 Gly-Gaba'
#  '312 CBX MLI Cdh22 Gaba' '035 OB Eomes Ms4a15 Glut'
#  '070 LSX Prdm12 Slit2 Gaba' '159 IF-RL-CLI-PAG Foxa1 Glut'
#  '306 SPVI-SPVC Sall3 Lhx1 Gly-Gaba' '328 OEC NN' '117 LHA Barhl2 Glut'
#  '029 L6b CTX Glut' '030 L6 CT CTX Glut' '057 NDB-SI-MA-STRv Lhx8 Gaba'
#  '028 L6b/CT ENT Glut' '010 IT AON-TT-DP Glut' '040 OB Trdn Gaba'
#  '052 Pvalb Gaba' '310 CBX Golgi Gly-Gaba' '060 OT D3 Folh1 Gaba'
#  '309 CB PLI Gly-Gaba' '331 Peri NN' '055 STR Lhx8 Gaba'
#  '293 PAS-MV Ebf2 Gly-Gaba' '265 PB Sst Gly-Gaba'
#  '287 MV-SPIV-PRP Dmbx1 Gly-Gaba' '270 LDT-DTN Gata3 Nfix Gaba'
#  '288 MDRN Hoxb5 Ebf2 Gly-Gaba' '273 PDTg-PCG Pax6 Gaba'
#  '290 MY Prox1 Lmo7 Gly-Gaba' '295 CBN Dmbx1 Gaba' '109 LGv-ZI Otx2 Gaba'
#  '279 PSV Pax2 Gly-Gaba' '297 CU-ECU Pax2 Gly-Gaba' '283 PRP Otp Gly-Gaba'
#  '315 DCO UBC Glut' '198 IC Six3 En2 Gaba' '280 NLL-po Pax7 Gaba'
#  '302 MV Xdh Gly-Gaba' '303 IRN Dmbx1 Pax2 Gly-Gaba' '101 ZI Pax6 Gaba'
#  '207 SCs Dmbx1 Gaba' '316 Bergmann NN' '208 SC Lef1 Otx2 Gaba'
#  '323 Ependymal NN' '326 OPC NN' '059 GPe-SI Sox6 Cyp26b1 Gaba'
#  '062 STR D2 Gaba' '330 VLMC NN' '329 ABC NN' '142 HY Gnrh1 Glut'
#  '262 Pineal Crx Glut' '317 Astro-CB NN' '119 SI-MA-LPO-LHA Skor1 Glut'
#  '002 IT EP-CLA Glut' '049 Lamp5 Gaba' '027 L6b EPd Glut'
#  '056 Sst Chodl Gaba' '050 Lamp5 Lhx6 Gaba' '043 OB-mi Frmd7 Gaba'
#  '046 Vip Gaba' '022 L5 ET CTX Glut' '006 L4/5 IT CTX Glut' '335 BAM NN'
#  '007 L2/3 IT CTX Glut' '023 SUB-ProS Glut' '021 L4 RSP-ACA Glut'
#  '325 CHOR NN' '019 L2/3 IT PPP Glut' '004 L6 IT CTX Glut'
#  '292 MV Nkx6-1 Gly-Gaba' '001 CLA-EPd-CTX Car3 Glut' '338 Lymphoid NN'
#  '003 L5/6 IT TPE-ENT Glut' '336 Monocytes NN' '337 DC NN'
#  '048 RHP-COA Ndnf Gaba' '016 CA1-ProS Glut' '014 LA-BLA-BMA-PA Glut'
#  '181 IC Tfap2d Maf Glut' '017 CA3 Glut' '074 MEA-BST Lhx6 Sp9 Gaba'
#  '187 SCsg Pde5a Glut' '020 L2/3 IT RSP Glut' '005 L5 IT CTX Glut'
#  '321 Astroependymal NN' '053 Sst Gaba' '013 COAp Grxcr2 Glut'
#  '111 TRS-BAC Sln Glut' '072 LSX Sall3 Lmo1 Gaba'
#  '071 LSX Prdm12 Zeb2 Gaba' '069 LSX Nkx2-1 Gaba' '061 STR D1 Gaba'
#  '054 STR Prox1 Lhx6 Gaba' '008 L2/3 IT ENT Glut' '025 CA2-FC-IG Glut'
#  '018 L2 IT PPP-APr Glut' '202 PRT Tcf7l2 Gaba' '211 SC Tnnt1 Gli3 Gaba'
#  '322 Tanycyte NN' '332 SMC NN' '305 SPVI-SPVC Sall3 Nfib Gly-Gaba'
#  '092 TMv-PMv Tbx3 Hist-Gaba' '213 SCsg Gabrr2 Gaba'
#  '015 ENTmv-PA-COAp Glut' '172 PAG Pou4f1 Ebf2 Glut'
#  '209 SCs Pax7 Nfia Gaba' '210 PRT Mecom Gaba' '151 TH Prkcd Grin2c Glut'
#  '212 SCs Lef1 Gli3 Gaba' '135 STN-PSTN Pitx2 Glut'
#  '133 PVH-SO-PVa Otp Glut' '178 SCig Foxb1 Otx2 Glut'
#  '094 SCH Six6 Cdc14a Gaba' '203 LGv-SPFp-SPFm Nkx2-2 Tcf7l2 Gaba'
#  '129 VMH Nr5a1 Glut' '093 RT-ZI Gnb3 Gaba' '175 SC Bnc2 Glut'
#  '113 MEA-COA-BMA Ccdc42 Glut' '204 SC Otx2 Gcnt4 Gaba'
#  '206 SCm-PAG Cdh23 Gaba' '114 COAa-PAA-MEA Barhl2 Glut'
#  '128 VMH Fezf1 Glut' '143 MM-ant Foxb1 Glut'
#  '196 PAG-PPN Pax5 Sox21 Gaba' '154 PF Fzd5 Glut' '152 RE-Xi Nox4 Glut'
#  '149 PVT-PT Ntrk1 Glut' '188 SCop Sln Glut' '144 MM Foxb1 Glut'
#  '084 BST-SI-AAA Six3 Slc22a3 Gaba' '200 PAG-ND-PCG Onecut1 Gaba'
#  '199 PAG-MRN-RN Foxa2 Gaba' '276 LDT-PCG St18 Gaba'
#  '215 SNc-VTA-RAmb Foxa1 Dopa' '126 ARH-PVp Tbx3 Glut'
#  '139 PH-LHA Foxb1 Glut' '269 LDT Fgf7 Gaba'
#  '186 SCop Pou4f2 Neurod2 Glut' '097 PVHd-SBPV Six3 Prox1 Gaba'
#  '078 SI-MA-ACB Ebf1 Bnc2 Gaba' '131 LHA-AHN-PVH Otp Trh Glut'
#  '257 SPVC Ccdc172 Glut' '231 IPN-LDT Vsx2 Nkx6-1 Glut'
#  '277 DTN-LDT-IPN Otp Pax3 Gaba' '205 SC-PAG Lef1 Emx2 Gaba'
#  '148 AV Col27a1 Glut' '141 PH-SUM Foxa1 Glut' '147 AD Serpinb7 Glut'
#  '033 NP SUB Glut' '073 MEA-BST Sox6 Gaba' '146 LH Pou4f1 Sox1 Glut'
#  '153 MG-POL-SGN Nts Glut' '103 PVHd-DMH Lhx6 Gaba'
#  '263 CS-RPO Meis2 Gaba' '214 IPN Otp Crisp1 Gaba'
#  '201 PAG-RN Nkx2-2 Otx1 Gaba' '137 PH-an Pitx2 Glut'
#  '104 TU-ARH Otp Six6 Gaba' '161 PAG Pou4f3 Glut'
#  '228 PSV Pvalb Lhx2 Glut' '166 MRN Pou3f1 C1ql4 Glut'
#  '098 AHN-SBPV-PVHd Pdrm12 Gaba' '192 PPN-CUN-PCG Otp En1 Gaba'
#  '121 MEA-BST Otp Zic2 Glut' '134 PH-ant-LHA Otp Bsx Glut'
#  '195 SNr-VTA Pax5 Npas1 Gaba' '089 PVR Six3 Sox3 Gaba'
#  '179 SCdg-PAG Tfap2b Glut' '086 MPO-ADP Lhx8 Gaba'
#  '267 CS-PRNr-PCG Tmem163 Otp Gaba' '110 BST-po Iigp1 Glut'
#  '082 CEA-BST Ebf1 Pdyn Gaba' '068 LSX Otx2 Gaba' '032 L5 NP CTX Glut'
#  '058 PAL-STR Gaba-Chol' '140 PMd-LHA Foxb1 Glut' '180 SCiw Pitx2 Glut'
#  '085 SI-MPO-LPO Lhx8 Gaba' '138 PH Pitx2 Glut'
#  '169 PAG-SC Pou4f1 Zic1 Glut' '083 CEA-BST Rai14 Pdyn Crh Gaba'
#  '223 B-PB Nr4a2 Glut' '047 Sncg Gaba' '011 L2 IT ENT-po Glut'
#  '163 APN C1ql2 Glut' '216 MB-MY Tph2 Glut-Sero'
#  '076 MEA-BST Lhx6 Nfib Gaba' '255 SPVO Mafa Meis2 Glut'
#  '063 STR D1 Sema5a Gaba' '031 CT SUB Glut' '012 MEA Slc17a7 Glut'
#  '075 MEA-BST Lhx6 Nr2e1 Gaba' '081 ACB-BST-FS D1 Gaba' '253 IO Fgl2 Glut'
#  '150 CM-IAD-CL-PCN Sema5b Glut' '165 PAG-MRN Pou3f1 Glut'
#  '051 Pvalb chandelier Gaba' '108 ARH-PVp Tbx3 Gaba'
#  '194 MRN-VTN-PPN Pax5 Cdh23 Gaba' '251 NTS Dbh Glut'
#  '232 LDT Vsx2 Nkx6-1 Nfib Glut' '024 L5 PPP Glut'
#  '268 CS-PRNr-DR En1 Sox2 Gaba' '136 PMv-TMv Pitx2 Glut'
#  '289 MDRNd Prox1 Pax6 Gly-Gaba' '100 AHN Onecut3 Gaba'
#  '118 ADP-MPO Trp73 Glut' '145 MH Tac2 Glut' '173 PAG Pou4f2 Glut'
#  '167 PRC-PAG Tcf7l2 Irx2 Glut' '116 AVPV-MEPO-SFO Tbr1 Glut'
#  '226 PRNc-PARN Tlx1 Glut' '191 PAG-MRN Rln3 Gaba'
#  '171 PAG Pou4f1 Bnc2 Glut' '107 DMH Hmx2 Gaba' '170 PAG-MRN Tfap2b Glut'
#  '162 CUN Evx2 Lhx2 Glut' '127 DMH-LHA Vgll2 Glut'
#  '225 PRNc-NI-SG-RPO Vsx2 Nr4a2 Glut' '088 BST Tac2 Gaba'
#  '237 PRP-NI-PRNc-GRN Otp Glut' '174 PAG Pou4f2 Mesi2 Glut'
#  '155 PRC-PAG Pax6 Glut' '099 SBPV-PVa Six6 Satb2 Gaba'
#  '256 SPVC Mafa Glut' '259 MDRNd Bves Glut' '294 MV Pax6 Gly-Gaba'
#  '087 MPN-MPO-LPO Lhx6 Zfhx3 Gaba' '079 CEA-BST Six3 Cyp26b1 Gaba'
#  '080 CEA-AAA-BST Six3 Sp9 Gaba' '281 POR Gata3 Gly-Gaba'
#  '090 BST-MPN Six3 Nrgn Gaba' '123 DMH Nkx2-4 Glut' '258 SPVC Nmu Glut'
#  '120 MEA Otp Foxp2 Glut' '183 PBG Mtnr1a Glut-Chol'
#  '272 LDT-PCG-CS Gata3 Lhx1 Gaba' '132 AHN-RCH-LHA Otp Fezf1 Glut'
#  '220 PB Pax5 Glut' '271 NI-RPO Gata3 Nr4a2 Gaba' '122 LHA-MEA Otp Glut'
#  '324 Hypendymal NN' '229 PB-NTS Phox2b Ebf3 Lmx1b Glut'
#  '158 MRN-PAG Nkx6-1 Glut' '230 PRNr Otp Nfib Glut'
#  '106 PVpo-VMPO-MPN Hmx2 Gaba' '190 ND-INC Foxd2 Glut'
#  '124 MPN-MPO-PVpo Hmx2 Glut' '130 LHA Pmch Glut' '125 DMH Hmx2 Glut'
#  '193 MRN-PPN-CUN Pax8 Gaba' '105 TMd-DMH Foxd2 Gaba'
#  '244 MV-SPIV Slc6a2 Glut' '236 IRN Vip Glut' '095 DMH Prdm13 Gaba'
#  '219 PB-SUT Tlx3 Lhx2 Glut' '291 NTS-MDRNd Prox1 Zic1 Gly-Gaba'
#  '240 MDRNv Lhx4 Qrfprl Glut' '286 PPY-PGRNl Vip Glyc-Gaba'
#  '077 CEA-BST Gal Avp Gaba' '299 MARN-PPY Ngfr Gly-Gaba'
#  '296 RPA Pax6 Hoxb5 Gly-Gaba' '300 PARN-MDRNd-NTS Gbx2 Gly-Gaba'
#  '227 PB-PSV Phox2b Glut' '234 MEV Ppp1r1c Glut' '301 MV Nr4a2 Gly-Gaba'
#  '096 PVHd Gsc Gaba' '091 ARH-PVi Six6 Dopa-Gaba'
#  '298 PRP Gata3 Slc6a5 Gly-Gaba' '284 GRN-IRN-MDRNd Ikzf1 Gly-Gaba'
#  '189 PAG Ucn Glut' '242 PGRNd Dmbx1 Glut' '112 GPi Tbr1 Cngb3 Gaba-Glut'
#  '184 PAG Tcf24 Glut' '307 RO-RPA Pkd2l1 Gaba' '274 PDTg Otp Shroom3 Gaba'
#  '275 PDTg Otp Olig3 Gaba' '239 MARN-GRN Pyy Glut' '249 NTS Aldh1a2 Glut'
#  '241 NTS Mbnl3 Glut' '266 PRNc Prox1 Brs3 Gly-Gaba' '260 MDRNv Crp Glut'
#  '034 NP PPP Glut' '026 NLOT Rho Glut' '067 LSX Sall3 Pax6 Gaba']
# --------------------------------------------------

# %%
# Filter check
filters = {
    'class': '08 CNU-MGE GABA',
    'neurotransmitter': 'Chol',
    'subclass': 'SI'
}
for col, val in filters.items():
    if col in joined.columns:
        if val in joined[col].unique():
            print(f"✅ Value '{val}' exists in column '{col}'")
        else:
            print(f"⚠ Value '{val}' NOT found in column '{col}'")
# Out:
# ✅ Value '08 CNU-MGE GABA' exists in column 'class'
# ✅ Value 'Chol' exists in column 'neurotransmitter'
# ⚠ Value 'SI' NOT found in column 'subclass'

# %%
# Apply filters
filtered = joined[
    (joined['class'] == '08 CNU-MGE GABA') &
    (joined['neurotransmitter'] == 'Chol')
]

print("Number of cells after filtering:", len(filtered))
print("Unique subclasses:", filtered['subclass'].unique())
print("Brain sections in filtered data:", filtered['brain_section_label'].unique()[:10])
# Out:
# Number of cells after filtering: 2858
# Unique subclasses: ['058 PAL-STR Gaba-Chol']
# Brain sections in filtered data: ['C57BL6J-638850.51' 'C57BL6J-638850.54' 'C57BL6J-638850.44'
#  'C57BL6J-638850.45' 'C57BL6J-638850.46' 'C57BL6J-638850.47'
#  'C57BL6J-638850.43' 'C57BL6J-638850.50' 'C57BL6J-638850.38'
#  'C57BL6J-638850.49']

# %%
blist = [f'C57BL6J-638850.{i}' for i in range(54, 43, -1)]
print("Selected brain sections:", blist)

# Filter to include those slices
filtered_all = joined[
    (joined['class'] == '08 CNU-MGE GABA') &
    (joined['neurotransmitter'] == 'Chol') &
    (joined['brain_section_label'].isin(blist))
]

print(f"Number of cells after filtering for all slices: {len(filtered_all)}")
print("Unique sections in filtered data:", filtered_all['brain_section_label'].unique())

# --- Aggregation by metadata (using all 10 slices) ---
def aggregate_by_metadata(df, gnames, value, sort = False):
    grouped = df.groupby(value)[gnames].mean()
    if sort:
        grouped = grouped.sort_values(by=gnames[0], ascending=False)
    return grouped

def plot_heatmap(df, fig_width = 8, fig_height = 4, cmap = plt.cm.magma_r, vmin = 0, vmax = 5):

    arr = df.to_numpy()

    fig, ax = plt.subplots()
    fig.set_size_inches(fig_width,fig_height)

    res = ax.imshow(arr, cmap=cmap, aspect='auto', vmin=vmin, vmax=vmax)
    xlabs = df.columns.values
    ylabs = df.index.values

    ax.set_xticks(range(len(xlabs)))
    ax.set_xticklabels(xlabs)

    ax.set_yticks(range(len(ylabs)))
    res = ax.set_yticklabels(ylabs)
    
final_genes = [g for g in target_genes if g in filtered_all.columns]

agg_nt = aggregate_by_metadata(filtered_all, final_genes, 'neurotransmitter', True)
plot_heatmap(agg_nt, 6, 3, vmax=3)
plt.title("By Neurotransmitter")
plt.show()

agg_class = aggregate_by_metadata(filtered_all, final_genes, 'class', True)
plot_heatmap(agg_class, 6, 5, vmax=3)
plt.title("By Cell Class")
plt.show()

agg_subclass = aggregate_by_metadata(filtered_all, final_genes, 'subclass', True)
plot_heatmap(agg_subclass, 6, 5, vmax=3)
plt.title("By Subclass")
plt.show()
# Out:
# Selected brain sections: ['C57BL6J-638850.54', 'C57BL6J-638850.53', 'C57BL6J-638850.52', 'C57BL6J-638850.51', 'C57BL6J-638850.50', 'C57BL6J-638850.49', 'C57BL6J-638850.48', 'C57BL6J-638850.47', 'C57BL6J-638850.46', 'C57BL6J-638850.45', 'C57BL6J-638850.44']
# Number of cells after filtering for all slices: 2398
# Unique sections in filtered data: ['C57BL6J-638850.51' 'C57BL6J-638850.54' 'C57BL6J-638850.44'
#  'C57BL6J-638850.45' 'C57BL6J-638850.46' 'C57BL6J-638850.47'
#  'C57BL6J-638850.50' 'C57BL6J-638850.49' 'C57BL6J-638850.52'
#  'C57BL6J-638850.48']

# %%
# Spatial plots for all slices (in a 2x5 grid)
def plot_sections_grid(df, feature, blist, cmap=plt.cm.magma_r, fig_width=25, fig_height=10):
    n_slices = len(blist)
    ncols = 5
    nrows = int(np.ceil(n_slices / ncols))
    fig, ax = plt.subplots(nrows, ncols, figsize=(fig_width, fig_height))
    ax = ax.flatten()

    for idx, bsl in enumerate(blist):
        filtered = df[df['brain_section_label'] == bsl]
        if filtered.empty:
            ax[idx].set_title(f"{bsl}\n(no cells)")
            ax[idx].axis("off")
            continue
        xx, yy, vv = filtered['x'], filtered['y'], filtered[feature]
        # Larger dot size for better visibility
        sc = ax[idx].scatter(xx, yy, s=15.0, c=vv, cmap=cmap, marker=".")
        ax[idx].axis('equal')
        ax[idx].set_xlim(0, 11)
        ax[idx].set_ylim(11, 0)
        ax[idx].set_xticks([])
        ax[idx].set_yticks([])
        ax[idx].set_title(bsl, fontsize=9)

    # Hide any unused subplots
    for j in range(idx + 1, len(ax)):
        ax[j].axis("off")

    # Add colorbar to the right of all plots
    cbar_ax = fig.add_axes([0.93, 0.15, 0.015, 0.7])
    fig.colorbar(sc, cax=cbar_ax, label='log2 Expression')
    plt.subplots_adjust(wspace=0.05, hspace=0.1)
    return fig, ax

# Plot each gene across all 10 slices
for g in target_genes:
    if g in filtered_all.columns:
        fig, ax = plot_sections_grid(filtered_all, g, blist, cmap=plt.cm.plasma) 
        fig.suptitle(f"Gene Expression: {g} (Slices 54–44)", fontsize=14)
        plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
# Compute mean and standard deviation for filtered cells
summary_stats = (
    filtered_all  # use your fully filtered dataset
    .groupby(['brain_section_label', 'class'])[target_genes]
    .agg(['mean', 'std'])
    .reset_index()
)

# Flatten MultiIndex columns
summary_stats.columns = [
    f"{col[0]}_{col[1]}" if col[1] else col[0]
    for col in summary_stats.columns
]

print("\nSummary statistics (mean ± std) for class CNU-MGE GABA with Chol neurotransmitter:")
print(summary_stats.head())
# Out:
# Summary statistics (mean ± std) for class CNU-MGE GABA with Chol neurotransmitter:
#   brain_section_label            class  Aif1_mean  Aif1_std  Gfap_mean  \
# 0   C57BL6J-638850.44  08 CNU-MGE GABA   0.155313  0.113972   0.036904
# 1   C57BL6J-638850.45  08 CNU-MGE GABA   0.142456  0.120108   0.030005
# 2   C57BL6J-638850.46  08 CNU-MGE GABA   0.135092  0.122636   0.021787
# 3   C57BL6J-638850.47  08 CNU-MGE GABA   0.119402  0.145109   0.018059
# 4   C57BL6J-638850.48  08 CNU-MGE GABA   0.134555  0.158482   0.019787
#
#    Gfap_std  S100b_mean  S100b_std  Ache_mean  Ache_std  Chat_mean  Chat_std
# 0  0.056141    0.812262   0.491932   7.691319  0.912639   9.027884  0.341394
# 1  0.068907    0.721927   0.424812   7.708177  0.751457   8.975136  0.261448
# 2  0.043394    0.750920   0.550398   7.747758  0.721100   8.969736  0.419928
# 3  0.039485    0.728526   0.660847   7.903378  0.713400   9.015013  0.273364
# 4  0.041790    0.868495   0.872451   7.778049  0.965061   9.010605  0.190868

# %%
# Melt the summary for plotting
summary_melted = filtered_all.melt(
    id_vars=['brain_section_label', 'class'],
    value_vars=target_genes,
    var_name='Gene',
    value_name='Expression'
)

plt.figure(figsize=(12, 6))
sns.barplot(
    data=summary_melted,
    x='brain_section_label',
    y='Expression',
    hue='Gene',
    ci='sd'  # Use standard deviation for error bars
)
plt.title('Mean Expression of Target Genes in CNU-MGE GABA (Chol) Across Brain Sections')
plt.ylabel('log2(Expression)')
plt.xlabel('Brain Section')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gene')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gs/nsc53bv90r1ghqzzq7v837sw0000gn/T/ipykernel_99114/2989050041.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
